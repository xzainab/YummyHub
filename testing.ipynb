# %%
import YummyHub

# %%
YummyHub.main()
# Out:
# WELCOME TO THE DIGITAL RECIPE BOOK
# This application helps you easily store, retrieve, and
# manage your favorite cooking recipes all in one place.
#
# === DIGITAL RECIPE BOOK ===
# 1. Add a new recipe
# 2. Search for a recipe by ingredient
# 3. View all recipes
# 4. Generate a random recipe
# 5. Rating recipes
# 6. Create a shopping list
# 7. Exit
# Enter your choice (1-7):  1
# === Add a New Recipe ===
# Enter recipe name:  cesser salad
# Please enter ingredients below (separated by commas OR one by one), then type 'done' when finished:
# Add ingredient(s):  lettuce
# Add ingredient(s):  Parmesan cheese
# Add ingredient(s):  Caesar dressing
# Add ingredient(s):  Grilled chicken
# Add ingredient(s):  done
# Enter preparation time in minutes:  20
# Please enter cooking instructions step-by-step. Type 'done' when finished:
# Step 1:  Wash and chop the lettuce
# Step 2:  add parmesan
# Step 3:  Pour in the Caesar dressing
# Step 4:  toss well
# Step 5:  Top with grilled chicken
# ...
