# %%
import YummyHub

# %%
YummyHub.main()
# Out:
# WELCOME TO THE DIGITAL RECIPE BOOK
# This application helps you easily store, retrieve, and
# manage your favorite cooking recipes all in one place.
#
# === DIGITAL RECIPE BOOK ===
# 1. Add a new recipe
# 2. Search for a recipe by ingredient
# 3. View all recipes
# 4. Generate a random recipe
# 5. Rating recipes
# 6. Sort by rating
# 7. Generate a shopping list
# 8. Exit
# Enter your choice (1-8):  5
# Enter recipe name:  baked salmon
# Enter a rating from 1 to 5:  3.8
# First rating recorded: 3.8/5.
#
# === DIGITAL RECIPE BOOK ===
# 1. Add a new recipe
# 2. Search for a recipe by ingredient
# 3. View all recipes
# 4. Generate a random recipe
# 5. Rating recipes
# 6. Sort by rating
# 7. Generate a shopping list
# 8. Exit
# Enter your choice (1-8):  6
#             name  rating
#        machboose     4.8
#            pasta     4.0
#   fruit smoothie     4.0
#    avocado toast     3.9
#     baked salmon     3.8
#         Pancakes     3.5
#     egg sandwich     2.5
# ...

# %%
import YummyHubFinal

# %%
YummyHubFinal.main()
# Out:
# WELCOME TO THE DIGITAL RECIPE BOOK
# This application helps you easily store, retrieve, and
# manage your favorite cooking recipes all in one place.
#
# === DIGITAL RECIPE BOOK ===
# 1. Add a new recipe
# 2. Search for a recipe by ingredient
# 3. View all recipes
# 4. Generate a random recipe
# 5. Rating recipes
# 6. Sort by rating
# 7. Exit
# Enter your choice (1-7):  1
# === Add a New Recipe ===
# Enter recipe name:  tea
# Please enter ingredients below (separated by commas OR one by one), then type 'done' when finished:
# Add ingredient(s):  water
# Add ingredient(s):  tea bag
# Add ingredient(s):  suger
# Add ingredient(s):  done
# Enter preparation time in minutes:  4
# Please enter cooking instructions step-by-step. Type 'done' when finished:
# Step 1:  boil the water
# Step 2:  add the tea bag into the cup
# Step 3:  add the boil water
# Step 4:  done
# Difficulty options: Easy, Medium, Hard
# Enter recipe difficulty level:  easy
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('recipes.csv')
df
# Out:
#         id              name  \
# 0   6aa5d9      egg sandwich
# 1   3c2851             pasta
# 2   5b0334         machboose
# 3   5e292e  chia seed boding
# 4   02621a      cesser salad
# 5   1cca8b          Pancakes
# 6   ec7ca2    fruit smoothie
# 7   70e6bc     avocado toast
# 8   b793b8      baked salmon
# 9   abcf4f           mrabyan
# 10  6166b7   turkey sandwich
# 11  33d107               tea
#
#                                           ingredients  preparing time  \
# 0               egg; tost; cheese; salt; black pepper              10
# 1   pasta; water; milk; cheese; tomato paste; oil;...              30
# 2                       rise; chicken; spices; potato              75
# 3   chia seeds; milk; mango; yogurt; blueberry; nu...             120
# 4   lettuce; Parmesan cheese; Caesar dressing; Gri...              20
# 5   flour; egg; milk; sugar; baking powder; oil; s...              20
# 6                   banana; berries; milk; honey; ice              10
# ...

# %%
df.loc[df['name'] == 'tea', df['category']] = 'Drink'

# %%
df
# Out:
#         id              name  \
# 0   6aa5d9      egg sandwich
# 1   3c2851             pasta
# 2   5b0334         machboose
# 3   5e292e  chia seed boding
# 4   02621a      cesser salad
# 5   1cca8b          Pancakes
# 6   ec7ca2    fruit smoothie
# 7   70e6bc     avocado toast
# 8   b793b8      baked salmon
# 9   abcf4f           mrabyan
# 10  6166b7   turkey sandwich
# 11  33d107               tea
#
#                                           ingredients  preparing time  \
# 0               egg; tost; cheese; salt; black pepper              10
# 1   pasta; water; milk; cheese; tomato paste; oil;...              30
# 2                       rise; chicken; spices; potato              75
# 3   chia seeds; milk; mango; yogurt; blueberry; nu...             120
# 4   lettuce; Parmesan cheese; Caesar dressing; Gri...              20
# 5   flour; egg; milk; sugar; baking powder; oil; s...              20
# 6                   banana; berries; milk; honey; ice              10
# ...

# %%
import pandas as pd

# 1. Load the CSV file
df2 = pd.read_csv("recipes.csv")

# 2. Modify the data
# Example A: Change a specific value based on a condition
df2.drop[df2["name"] == "tea"].index.tolist()

df2

# 3. Save the changes back to the CSV
df2.to_csv("recipes.csv", index=False)

# %%
df2
# Out:
#         id              name  \
# 0   6aa5d9      egg sandwich
# 1   3c2851             pasta
# 2   5b0334         machboose
# 3   5e292e  chia seed boding
# 4   02621a      cesser salad
# 5   1cca8b          Pancakes
# 6   ec7ca2    fruit smoothie
# 7   70e6bc     avocado toast
# 8   b793b8      baked salmon
# 9   abcf4f           mrabyan
# 10  6166b7   turkey sandwich
#
#                                           ingredients  preparing time  \
# 0               egg; tost; cheese; salt; black pepper              10
# 1   pasta; water; milk; cheese; tomato paste; oil;...              30
# 2                       rise; chicken; spices; potato              75
# 3   chia seeds; milk; mango; yogurt; blueberry; nu...             120
# 4   lettuce; Parmesan cheese; Caesar dressing; Gri...              20
# 5   flour; egg; milk; sugar; baking powder; oil; s...              20
# 6                   banana; berries; milk; honey; ice              10
# ...
